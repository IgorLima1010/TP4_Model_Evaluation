# %% [markdown]
# #TP4 NLP: Criação do baseline
#
#
#
# ----
# Aluno PPGI: Igor de Souza Lima

# %%
import os
if "COLAB_" not in "".join(os.environ.keys()):
    # !pip install unsloth
else:
    # !pip install --no-deps bitsandbytes accelerate xformers==0.0.29.post3 peft trl==0.15.2 triton cut_cross_entropy unsloth_zoo
    # !pip install sentencepiece protobuf "datasets>=3.4.1" huggingface_hub hf_transfer
    # !pip install transformers==4.51.3
    # !pip install --no-deps unsloth
# Out:
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.46.0-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.7.0)
# Collecting xformers==0.0.29.post3
#   Downloading xformers-0.0.29.post3-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (1.0 kB)
# Requirement already satisfied: peft in /usr/local/lib/python3.11/dist-packages (0.15.2)
# Collecting trl==0.15.2
#   Downloading trl-0.15.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: triton in /usr/local/lib/python3.11/dist-packages (3.2.0)
# Collecting cut_cross_entropy
#   Downloading cut_cross_entropy-25.1.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting unsloth_zoo
#   Downloading unsloth_zoo-2025.6.2-py3-none-any.whl.metadata (8.1 kB)
# Downloading xformers-0.0.29.post3-cp311-cp311-manylinux_2_28_x86_64.whl (43.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.4/43.4 MB 24.8 MB/s eta 0:00:00
# Downloading trl-0.15.2-py3-none-any.whl (318 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 28.7 MB/s eta 0:00:00
# Downloading bitsandbytes-0.46.0-py3-none-manylinux_2_24_x86_64.whl (67.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 11.4 MB/s eta 0:00:00
# Downloading cut_cross_entropy-25.1.1-py3-none-any.whl (22 kB)
# Downloading unsloth_zoo-2025.6.2-py3-none-any.whl (149 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.1/149.1 kB 14.7 MB/s eta 0:00:00
# Installing collected packages: xformers, unsloth_zoo, trl, cut_cross_entropy, bitsandbytes
# Successfully installed bitsandbytes-0.46.0 cut_cross_entropy-25.1.1 trl-0.15.2 unsloth_zoo-2025.6.2 xformers-0.0.29.post3
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (0.2.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (5.29.5)
# Collecting datasets>=3.4.1
#   Downloading datasets-3.6.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.11/dist-packages (0.33.0)
# Requirement already satisfied: hf_transfer in /usr/local/lib/python3.11/dist-packages (0.1.9)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets>=3.4.1) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets>=3.4.1) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=3.4.1) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=3.4.1) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets>=3.4.1) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets>=3.4.1) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets>=3.4.1) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets>=3.4.1) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets>=3.4.1) (0.70.15)
# Collecting fsspec<=2025.3.0,>=2023.1.0 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.4.1)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets>=3.4.1) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets>=3.4.1) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (1.1.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.4.1) (3.11.15)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=3.4.1) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=3.4.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=3.4.1) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=3.4.1) (2025.6.15)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=3.4.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=3.4.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=3.4.1) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.4.1) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.4.1) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.4.1) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.4.1) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.4.1) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.4.1) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.4.1) (1.20.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=3.4.1) (1.17.0)
# Downloading datasets-3.6.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 26.4 MB/s eta 0:00:00
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 17.5 MB/s eta 0:00:00
# Installing collected packages: fsspec, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
#   Attempting uninstall: datasets
#     Found existing installation: datasets 2.14.4
#     Uninstalling datasets-2.14.4:
#       Successfully uninstalled datasets-2.14.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# unsloth-zoo 2025.6.2 requires msgspec, which is not installed.
# unsloth-zoo 2025.6.2 requires tyro, which is not installed.
# unsloth-zoo 2025.6.2 requires protobuf<4.0.0, but you have protobuf 5.29.5 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-nvrtc-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-nvrtc-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-runtime-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-runtime-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 9.3.0.75 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.2.3.61 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.6.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.6.3.83 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.5.1.3 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.5.82 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# Successfully installed datasets-3.6.0 fsspec-2025.3.0
# Collecting transformers==4.51.3
#   Downloading transformers-4.51.3-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers==4.51.3) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.51.3) (0.33.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.51.3) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.51.3) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.51.3) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.51.3) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers==4.51.3) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers==4.51.3) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers==4.51.3) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers==4.51.3) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers==4.51.3) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers==4.51.3) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers==4.51.3) (1.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.51.3) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.51.3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.51.3) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.51.3) (2025.6.15)
# Downloading transformers-4.51.3-py3-none-any.whl (10.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 127.8 MB/s eta 0:00:00
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.52.4
#     Uninstalling transformers-4.52.4:
#       Successfully uninstalled transformers-4.52.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# unsloth-zoo 2025.6.2 requires msgspec, which is not installed.
# unsloth-zoo 2025.6.2 requires tyro, which is not installed.
# unsloth-zoo 2025.6.2 requires protobuf<4.0.0, but you have protobuf 5.29.5 which is incompatible.
# Successfully installed transformers-4.51.3
# Collecting unsloth
#   Downloading unsloth-2025.6.3-py3-none-any.whl.metadata (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.1/47.1 kB 4.0 MB/s eta 0:00:00
# Downloading unsloth-2025.6.3-py3-none-any.whl (277 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 277.9/277.9 kB 20.8 MB/s eta 0:00:00
# Installing collected packages: unsloth
# Successfully installed unsloth-2025.6.3

# %%
import json
import sqlite3
import os
import torch
from unsloth import FastLanguageModel

# --- 1. CONFIGURAÇÃO DOS CAMINHOS E PARÂMETROS ---
DEV_FILE = "/dados/dev.json"
PROMPT_TEMPLATE_FILE = "/dados/prompt_template.txt"
DATABASE_DIR = "/dados/"  # Diretório que contém a pasta 'database'
SEED = 42

TEMPERATURE = 0.1
TOP_P = 0.95

# --- 2. FUNÇÃO OTIMIZADA E CORRIGIDA PARA CHAMAR O MODELO ---
def chamar_meu_modelo(model, tokenizer, prompt: str) -> str:
    """
    Recebe o modelo e o tokenizador já carregados e o prompt para gerar a consulta SQL.
    Esta versão foi corrigida para extrair APENAS a resposta do assistente.
    """
    messages = [
        {"role": "user", "content": prompt},
    ]

    inputs = tokenizer.apply_chat_template(
        messages,
        tokenize=True,
        add_generation_prompt=True,
        return_tensors="pt",
    ).to("cuda")

    outputs = model.generate(
        input_ids=inputs,
        max_new_tokens=256,
        use_cache=True,
        do_sample=True,
        temperature=TEMPERATURE,
        top_p=TOP_P,
    )

    # Decodifica a saída completa
    full_response = tokenizer.batch_decode(outputs, skip_special_tokens=True)[0]

    # **INÍCIO DA LÓGICA DE CORREÇÃO**
    try:
        # 1. Isola a parte da resposta do assistente usando o separador do Llama 3
        assistant_tag = "assistant\n\n" # O template do Llama 3 insere isso após o header.
        assistant_part = full_response.split(assistant_tag)[-1].strip()

        # 2. Procura por um bloco de código SQL dentro da resposta
        sql_block_start = assistant_part.find("```sql")
        if sql_block_start != -1:
            # Se encontrou o início do bloco, procura o fim
            sql_block_end = assistant_part.rfind("```")
            if sql_block_end > sql_block_start:
                # Extrai o conteúdo entre as tags ```sql e ```
                sql_code = assistant_part[sql_block_start + len("```sql") : sql_block_end].strip()
                return sql_code

        # 3. Se não houver bloco de código, retorna a resposta do assistente como está
        # (pode ser que o modelo tenha retornado apenas a SQL diretamente)
        return assistant_part

    except Exception:
        # Se qualquer parte da extração falhar, retorna a resposta completa como último recurso
        return full_response
    # **FIM DA LÓGICA DE CORREÇÃO**

# --- 3. LÓGICA PRINCIPAL DA AVALIAÇÃO (sem alterações) ---
def avaliar_baseline(model, tokenizer):
    try:
        with open(DEV_FILE, 'r', encoding='utf-8') as f:
            dev_data = json.load(f)
        with open(PROMPT_TEMPLATE_FILE, 'r', encoding='utf-8') as f:
            prompt_template = f.read()
    except FileNotFoundError as e:
        print(f"Erro: Arquivo não encontrado - {e}. Verifique os caminhos.")
        return

    sucessos = 0
    falhas = 0
    total = len(dev_data)

    for i, item in enumerate(dev_data):
        pergunta = item['question']
        db_id = item['db_id']
        sql_correta = item['query']

        print(f"\n--- AVALIANDO ITEM {i+1}/{total} | BANCO DE DADOS: {db_id} ---")
        print(f"PERGUNTA: {pergunta}")

        prompt_final = prompt_template.replace('{your_new_question_here}', pergunta)
        sql_gerada = chamar_meu_modelo(model, tokenizer, prompt_final)

        # Remove ponto e vírgula do final, se houver, para evitar erros no SQLite
        if sql_gerada.endswith(';'):
            sql_gerada = sql_gerada[:-1]

        print(f"SQL GERADA: {sql_gerada}")
        print(f"SQL CORRETA: {sql_correta}")

        db_path = os.path.join(DATABASE_DIR, 'database', db_id, f'{db_id}.sqlite')

        if not os.path.exists(db_path):
            print(f"  -> FALHA (Erro: Banco de dados não encontrado em '{db_path}')")
            falhas += 1
            continue

        try:
            conn = sqlite3.connect(db_path)
            cursor_gerada = conn.cursor()
            cursor_correta = conn.cursor()

            cursor_gerada.execute(sql_gerada)
            resultado_gerado = cursor_gerada.fetchall()

            cursor_correta.execute(sql_correta)
            resultado_correto = cursor_correta.fetchall()

            if resultado_gerado == resultado_correto:
                print("  -> SUCESSO (Resultados idênticos)")
                sucessos += 1
            else:
                print("  -> FALHA (Resultado diferente do esperado)")
                falhas += 1

        except sqlite3.Error as e:
            print(f"  -> FALHA (Erro de execução SQL: {e})")
            falhas += 1

        finally:
            if 'conn' in locals():
                conn.close()

    # --- 4. EXIBIR RESULTADOS FINAIS ---
    print("\n\n--- AVALIAÇÃO DO BASELINE CONCLUÍDA ---")
    print(f"Total de Perguntas Avaliadas: {total}")
    print(f"Sucessos: {sucessos}")
    print(f"Falhas: {falhas}")

    taxa_de_sucesso = (sucessos / total) * 100 if total > 0 else 0
    print(f"Taxa de Sucesso (Execution Accuracy): {taxa_de_sucesso:.2f}%")


if __name__ == '__main__':
    torch.manual_seed(SEED)

    print("Carregando o modelo e o tokenizador...")
    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name="unsloth/Llama-3.2-3B-Instruct-bnb-4bit",
        max_seq_length=2048,
        dtype=None,
        load_in_4bit=True,
    )

    FastLanguageModel.for_inference(model)
    print("Modelo carregado com sucesso.")

    avaliar_baseline(model, tokenizer)
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# FROM tv_series AS T1
# ORDER BY T1.rating DESC
# LIMIT 3
# SQL CORRETA: SELECT Episode ,  Rating FROM TV_series ORDER BY Rating DESC LIMIT 3;
#   -> SUCESSO (Resultados idênticos)
#
# --- AVALIANDO ITEM 617/1034 | BANCO DE DADOS: tvshow ---
# PERGUNTA: What are 3 most highly rated episodes in the TV series table and what were those ratings?
# SQL GERADA: SELECT title, rating
# FROM tv_series
# ORDER BY rating DESC
# LIMIT 3
# SQL CORRETA: SELECT Episode ,  Rating FROM TV_series ORDER BY Rating DESC LIMIT 3;
#   -> FALHA (Erro de execução SQL: no such column: title)
#
# --- AVALIANDO ITEM 618/1034 | BANCO DE DADOS: tvshow ---
# PERGUNTA: What is minimum and maximum share of TV series?
# SQL GERADA: SELECT
#     (min(tv_series.num_episodes) / (SELECT COUNT(*) FROM tv_series)) AS min_share,
#     (max(tv_series.num_episodes) / (SELECT COUNT(*) FROM tv_series)) AS max_share
# FROM
#     tv_series
# SQL CORRETA: SELECT max(SHARE) , min(SHARE) FROM TV_series;
#   -> FALHA (Erro de execução SQL: no such column: tv_series.num_episodes)
#
# --- AVALIANDO ITEM 619/1034 | BANCO DE DADOS: tvshow ---
# PERGUNTA: What is the maximum and minimum share for the TV series?
# SQL GERADA: SELECT MAX(share) AS max_share, MIN(share) AS min_share
# FROM show
# WHERE genre = 'TV series'
# SQL CORRETA: SELECT max(SHARE) , min(SHARE) FROM TV_series;
#   -> FALHA (Erro de execução SQL: no such table: show)
#
# --- AVALIANDO ITEM 620/1034 | BANCO DE DADOS: tvshow ---
# PERGUNTA: What is the air date of TV series with Episode "A Love of a Lifetime"?
# SQL GERADA: SELECT air_date
# FROM tv_series
# WHERE title = 'A Love of a Lifetime'
# SQL CORRETA: SELECT Air_Date FROM TV_series WHERE Episode = "A Love of a Lifetime";
#   -> FALHA (Erro de execução SQL: no such column: title)
#
# --- AVALIANDO ITEM 621/1034 | BANCO DE DADOS: tvshow ---
# PERGUNTA: When did the episode "A Love of a Lifetime" air?
# SQL GERADA: To translate the natural language question "When did the episode 'A Love of a Lifetime' air?" into a SQL query, we need to identify the relevant tables and columns.
#
# Assuming that the episode information is stored in a table called 'episodes' and the air dates are stored in a column called 'air_date', the SQL query would be:
#
# SELECT air_date FROM episodes WHERE title = 'A Love of a Lifetime'
#
# This query selects the air_date column from the episodes table where the title column is equal to 'A Love of a Lifetime'.
# SQL CORRETA: SELECT Air_Date FROM TV_series WHERE Episode = "A Love of a Lifetime";
#   -> FALHA (Erro de execução SQL: near "To": syntax error)
#
# --- AVALIANDO ITEM 622/1034 | BANCO DE DADOS: tvshow ---
# PERGUNTA: What is Weekly Rank of TV series with Episode "A Love of a Lifetime"?
# SQL GERADA: SELECT tvs.weekly_rank
# FROM tv_series AS tvs
# JOIN tv_series_episode AS tse ON tvs.tv_series_id = tse.tv_series_id
# JOIN episode AS e ON tse.episode_id = e.episode_id
# WHERE e.title = 'A Love of a Lifetime'
# SQL CORRETA: SELECT Weekly_Rank FROM TV_series WHERE Episode = "A Love of a Lifetime";
#   -> FALHA (Erro de execução SQL: no such table: tv_series_episode)
#
# --- AVALIANDO ITEM 623/1034 | BANCO DE DADOS: tvshow ---
# PERGUNTA: What is the weekly rank for the episode "A Love of a Lifetime"?
# SQL GERADA: SELECT T1.weekly_rank
# FROM episodes AS T1
# JOIN episodes_table AS T2 ON T1.id = T2.id
# WHERE T2.episode_name = 'A Love of a Lifetime';
# ```
#
# However, this query may not be efficient if the "episodes" table is very large, as it would require joining the table with itself. A more efficient approach would be to use a single table with the necessary columns, like this:
#
# ```sql
# SELECT weekly_rank
# FROM episodes
# WHERE episode_name = 'A Love of a Lifetime'
# SQL CORRETA: SELECT Weekly_Rank FROM TV_series WHERE Episode = "A Love of a Lifetime";
#   -> FALHA (Erro de execução SQL: no such table: episodes)
#
# --- AVALIANDO ITEM 624/1034 | BANCO DE DADOS: tvshow ---
# PERGUNTA: What is the TV Channel of TV series with Episode "A Love of a Lifetime"? List the TV Channel's series name.
# SQL GERADA: SELECT T1.tv_channel, T1.series_name FROM tv_series AS T1 JOIN episode AS T2 ON T1.tv_series_id = T2.tv_series_id WHERE T2.episode_name = 'A Love of a Lifetime'
# SQL CORRETA: SELECT T1.series_name FROM TV_Channel AS T1 JOIN TV_series AS T2 ON T1.id = T2.Channel WHERE T2.Episode = "A Love of a Lifetime";
#   -> FALHA (Erro de execução SQL: no such table: episode)
#
# --- AVALIANDO ITEM 625/1034 | BANCO DE DADOS: tvshow ---
# PERGUNTA: What is the name of the series that has the episode "A Love of a Lifetime"?
# SQL GERADA: SELECT T1.series_name
# FROM movie AS T1
# JOIN episode AS T2 ON T1.movie_id = T2.movie_id
# WHERE T2.episode_name = 'A Love of a Lifetime'
# SQL CORRETA: SELECT T1.series_name FROM TV_Channel AS T1 JOIN TV_series AS T2 ON T1.id = T2.Channel WHERE T2.Episode = "A Love of a Lifetime";
#   -> FALHA (Erro de execução SQL: no such table: movie)
#
# --- AVALIANDO ITEM 626/1034 | BANCO DE DADOS: tvshow ---
# PERGUNTA: List the Episode of all  TV series showed on TV Channel with series name "Sky Radio".
# SQL GERADA: SELECT T1.episode
# FROM tv_series AS T1
# JOIN tv_channel AS T2 ON T1.tv_channel_id = T2.tv_channel_id
# WHERE T1.series_name = 'Sky Radio'
# SQL CORRETA: SELECT T2.Episode FROM TV_Channel AS T1 JOIN TV_series AS T2 ON T1.id = T2.Channel WHERE T1.series_name = "Sky Radio";
#   -> FALHA (Erro de execução SQL: no such column: T1.series_name)
#
# --- AVALIANDO ITEM 627/1034 | BANCO DE DADOS: tvshow ---
# PERGUNTA: What is the episode for the TV series named "Sky Radio"?
# SQL GERADA: SELECT T1.episode
# FROM tv_series AS T1
# JOIN episodes AS T2 ON T1.tv_series_id = T2.tv_series_id
# WHERE T1.name = 'Sky Radio'
# SQL CORRETA: SELECT T2.Episode FROM TV_Channel AS T1 JOIN TV_series AS T2 ON T1.id = T2.Channel WHERE T1.series_name = "Sky Radio";
#   -> FALHA (Erro de execução SQL: no such table: episodes)
#
# --- AVALIANDO ITEM 628/1034 | BANCO DE DADOS: tvshow ---
# PERGUNTA: Find the number of cartoons directed by each of the listed directors.
# SQL GERADA: SELECT director, COUNT(*) AS num_cartoons
# FROM movie
# WHERE genre = 'cartoon'
# GROUP BY director;
# ```
#
# This query works as follows:
#
# - It selects the `director` column and counts the number of rows for each director using the `COUNT(*)` function.
# - It filters the results to only include rows where the `genre` is 'cartoon'.
# - It groups the results by the `director` column, so that the count is calculated separately for each director.
#
# However, since the problem statement does not specify the listed directors, we will assume that the directors are specified in the `movie` table. If the directors are specified in a different table, you would need to join that table to the `movie` table.
#
# For example, if the directors are specified in a `director` table, you would use the following query:
#
# ```sql
# SELECT d.director, COUNT(*) AS num_cartoons
# FROM movie m
# JOIN director d ON m.director_id = d.director_id
# WHERE m.genre = 'cartoon'
# GROUP BY d.director
# SQL CORRETA: SELECT count(*) ,  Directed_by FROM cartoon GROUP BY Directed_by
#   -> FALHA (Erro de execução SQL: no such table: movie)
#
# --- AVALIANDO ITEM 629/1034 | BANCO DE DADOS: tvshow ---
# PERGUNTA: How many cartoons did each director create?
# SQL GERADA: To answer the final task, we need to translate the natural language question into a SQL query. Here's the solution:
#
# Question: How many cartoons did each director create?
#
# SQL:
# SELECT director, COUNT(*) AS num_cartoons
# FROM movie
# WHERE genre = 'cartoon'
# GROUP BY director
# SQL CORRETA: SELECT count(*) ,  Directed_by FROM cartoon GROUP BY Directed_by
#   -> FALHA (Erro de execução SQL: near "To": syntax error)
#
# --- AVALIANDO ITEM 630/1034 | BANCO DE DADOS: tvshow ---
# PERGUNTA: Find the production code and channel of the most recently aired cartoon .
# SQL GERADA: SELECT T1.production_code, T1.channel
# FROM cartoon AS T1
# WHERE T1.air_date = (SELECT MAX(air_date) FROM cartoon)
# SQL CORRETA: select production_code ,  channel from cartoon order by original_air_date desc limit 1
#   -> FALHA (Erro de execução SQL: no such column: T1.air_date)
#
# --- AVALIANDO ITEM 631/1034 | BANCO DE DADOS: tvshow ---
# PERGUNTA: What is the produdction code and channel of the most recent cartoon ?
# SQL GERADA: SELECT production_code, channel
# FROM cartoon
# ORDER BY release_year DESC
# LIMIT 1
# SQL CORRETA: select production_code ,  channel from cartoon order by original_air_date desc limit 1
#   -> FALHA (Erro de execução SQL: no such column: release_year)
#
# --- AVALIANDO ITEM 632/1034 | BANCO DE DADOS: tvshow ---
# PERGUNTA: Find the package choice and series name of the TV channel that has high definition TV.
# SQL GERADA: SELECT package_choice, series_name
# FROM tv_channel
# WHERE hd_tv = 'Yes'
# SQL CORRETA: SELECT package_option ,  series_name FROM TV_Channel WHERE hight_definition_TV  =  "yes"
#   -> FALHA (Erro de execução SQL: no such column: package_choice)
#
# --- AVALIANDO ITEM 633/1034 | BANCO DE DADOS: tvshow ---
# PERGUNTA: What are the package options and the name of the series for the TV Channel that supports high definition TV?
# SQL GERADA: To translate the given natural language question into a SQL query, we need to identify the relevant tables, columns, joins, and aggregations.
#
# The question is: "What are the package options and the name of the series for the TV Channel that supports high definition TV?"
#
# Based on the provided examples, we can assume the following table structure:
#
# - `movie`: This table contains information about movies, including `title`, `YEAR`, `director`, and `budget_million`.
# - `culture_company`: This table contains information about companies, including `company_name` and `book_club_id`.
# - `book_club`: This table contains information about book clubs, including `publisher` and `book_club_id`.
# - `tv_channel`: This table contains information about TV channels, including `channel_name` and `package_options`.
#
# To answer the question, we need to join the `movie` table with the `tv_channel` table and filter the results to include only TV channels that support high definition TV. We also need to join the `culture_company` table with the `book_club` table to filter the results to include only book clubs published by Alyson.
#
# Here's the SQL query:
#
# ```sql
# SELECT T1.package_options, T1.channel_name
# SQL CORRETA: SELECT package_option ,  series_name FROM TV_Channel WHERE hight_definition_TV  =  "yes"
#   -> FALHA (Erro de execução SQL: near "To": syntax error)
#
# --- AVALIANDO ITEM 634/1034 | BANCO DE DADOS: tvshow ---
# PERGUNTA: which countries' tv channels are playing some cartoon written by Todd Casey?
# SQL GERADA: SELECT T1.country
# FROM movie AS T1
# JOIN tv_channel AS T2 ON T1.country = T2.country
# JOIN cartoon AS T3 ON T1.title = T3.title
# WHERE T3.writer = 'Todd Casey'
# SQL CORRETA: SELECT T1.country FROM TV_Channel AS T1 JOIN cartoon AS T2 ON T1.id = T2.Channel WHERE T2.written_by  =  'Todd Casey'
#   -> FALHA (Erro de execução SQL: no such table: movie)
#
# --- AVALIANDO ITEM 635/1034 | BANCO DE DADOS: tvshow ---
# PERGUNTA: What are the countries that have cartoons on TV that were written by Todd Casey?
# SQL GERADA: SELECT T1.country
# FROM culture_company AS T1
# JOIN book_club AS T2 ON T1.book_club_id = T2.book_club_id
# WHERE T2.publisher = 'Todd Casey' AND T1.cartoon = 'TV';
# ```
# However, the above query may not be accurate because the 'cartoon' column in the culture_company table may not directly indicate if the company produces cartoons for TV. A more accurate query would be:
# SQL CORRETA: SELECT T1.country FROM TV_Channel AS T1 JOIN cartoon AS T2 ON T1.id = T2.Channel WHERE T2.written_by  =  'Todd Casey'
#   -> FALHA (Erro de execução SQL: no such table: culture_company)
#
# --- AVALIANDO ITEM 636/1034 | BANCO DE DADOS: tvshow ---
# PERGUNTA: which countries' tv channels are not playing any cartoon written by Todd Casey?
# SQL GERADA: To translate the given natural language question into a SQL query, we need to break down the question and identify the relevant tables, columns, joins, and aggregations.
#
# Question: which countries' tv channels are not playing any cartoon written by Todd Casey?
#
# Table: culture_company (contains information about companies)
# Table: book_club (contains information about books and their publishers)
# Table: movie (contains information about movies)
#
# Columns:
# - culture_company: company_name
# - book_club: book_club_id, publisher
# - movie: title, YEAR, director, budget_million
#
# Join: culture_company and book_club on book_club_id
# Join: book_club and movie on book_club_id
#
# Aggregation: None
#
# SQL Query:
# ```sql
# SELECT T1.country_name
# FROM culture_company AS T1
# LEFT JOIN book_club AS T2 ON T1.book_club_id = T2.book_club_id
# LEFT JOIN movie AS T3 ON T2.book_club_id = T3.book_club_id
# WHERE T3.title LIKE '%cartoon%' AND T3.director = 'Todd Casey'
# AND T1.company_name NOT IN (
#   SELECT T4.publisher
#   FROM book_club AS T4
#   WHERE
# SQL CORRETA: SELECT country FROM TV_Channel EXCEPT SELECT T1.country FROM TV_Channel AS T1 JOIN cartoon AS T2 ON T1.id = T2.Channel WHERE T2.written_by  =  'Todd Casey'
#   -> FALHA (Erro de execução SQL: near "To": syntax error)
#
# --- AVALIANDO ITEM 637/1034 | BANCO DE DADOS: tvshow ---
# PERGUNTA: What are the countries that are not playing cartoons written by Todd Casey?
# SQL GERADA: SELECT T1.country
# FROM movie AS T1
# LEFT JOIN culture_company AS T2 ON T1.country_id = T2.country_id
# LEFT JOIN book_club AS T3 ON T2.book_club_id = T3.book_club_id
# WHERE T3.publisher = 'Alyson' AND T1.title NOT LIKE '%cartoon%' AND T1.director = 'Todd Casey'
# SQL CORRETA: SELECT country FROM TV_Channel EXCEPT SELECT T1.country FROM TV_Channel AS T1 JOIN cartoon AS T2 ON T1.id = T2.Channel WHERE T2.written_by  =  'Todd Casey'
#   -> FALHA (Erro de execução SQL: no such table: movie)
#
# --- AVALIANDO ITEM 638/1034 | BANCO DE DADOS: tvshow ---
# PERGUNTA: Find the series name and country of the tv channel that is playing some cartoons directed by Ben Jones and Michael Chang?
# SQL GERADA: To translate the given natural language question into a SQL query, we need to break down the question and identify the relevant tables, columns, joins, and aggregations.
#
# Question: Find the series name and country of the tv channel that is playing some cartoons directed by Ben Jones and Michael Chang?
#
# Let's analyze the question:
#
# - The tv channel is playing cartoons.
# - The cartoons are directed by Ben Jones and Michael Chang.
# - We need to find the series name and country of the tv channel.
#
# Based on the provided examples, we can infer that:
#
# - The table for tv channels is `tv_channel`.
# - The table for cartoons is `cartoon`.
# - The table for directors is `director`.
# - The table for series is `series`.
#
# We can join these tables based on the relationships between them. The `cartoon` table has a foreign key `director_id` that references the `id` column in the `director` table. The `cartoon` table also has a foreign key `tv_channel_id` that references the `id` column in the `tv_channel` table. The `cartoon` table has a foreign key `series_id` that references the `id` column in the `series` table.
#
# Here's the SQL query:
#
# ```sql
# SQL CORRETA: SELECT T1.series_name ,  T1.country FROM TV_Channel AS T1 JOIN cartoon AS T2 ON T1.id = T2.Channel WHERE T2.directed_by  =  'Michael Chang' INTERSECT SELECT T1.series_name ,  T1.country FROM TV_Channel AS T1 JOIN cartoon AS T2 ON T1.id = T2.Channel WHERE T2.directed_by  =  'Ben Jones'
#   -> FALHA (Erro de execução SQL: near "To": syntax error)
#
# --- AVALIANDO ITEM 639/1034 | BANCO DE DADOS: tvshow ---
# PERGUNTA: What is the series name and country of all TV channels that are playing cartoons directed by Ben Jones and cartoons directed by Michael Chang?
# SQL GERADA: SELECT
#     T1.series_name,
#     T1.country
# FROM
#     tv_channel AS T1
# JOIN
#     cartoon AS T2 ON T1.country = T2.country
# WHERE
#     T2.director = 'Ben Jones'
#     OR T2.director = 'Michael Chang'
# SQL CORRETA: SELECT T1.series_name ,  T1.country FROM TV_Channel AS T1 JOIN cartoon AS T2 ON T1.id = T2.Channel WHERE T2.directed_by  =  'Michael Chang' INTERSECT SELECT T1.series_name ,  T1.country FROM TV_Channel AS T1 JOIN cartoon AS T2 ON T1.id = T2.Channel WHERE T2.directed_by  =  'Ben Jones'
#   -> FALHA (Erro de execução SQL: no such column: T2.director)
#
# --- AVALIANDO ITEM 640/1034 | BANCO DE DADOS: tvshow ---
# PERGUNTA: find the pixel aspect ratio and nation of the tv channels that do not use English.
# SQL GERADA: SELECT
#     pixel_aspect_ratio,
#     nation
# FROM
#     tv_channel
# WHERE
#     language!= 'English'
# SQL CORRETA: SELECT Pixel_aspect_ratio_PAR ,  country FROM tv_channel WHERE LANGUAGE != 'English'
#   -> FALHA (Erro de execução SQL: no such column: pixel_aspect_ratio)
#
# --- AVALIANDO ITEM 641/1034 | BANCO DE DADOS: tvshow ---
# PERGUNTA: What is the pixel aspect ratio and country of origin for all TV channels that do not use English?
# SQL GERADA: SELECT
#   channel_settings.pixel_aspect_ratio,
#   tv_channels.country_of_origin
# FROM
#   tv_channels
#   LEFT JOIN channel_settings ON tv_channels.channel_id = channel_settings.channel_id
# WHERE
#   tv_channels.language!= 'English'
# SQL CORRETA: SELECT Pixel_aspect_ratio_PAR ,  country FROM tv_channel WHERE LANGUAGE != 'English'
#   -> FALHA (Erro de execução SQL: no such table: tv_channels)
#
# --- AVALIANDO ITEM 642/1034 | BANCO DE DADOS: tvshow ---
# PERGUNTA: find id of the tv channels that from the countries where have more than two tv channels.
# SQL GERADA: SELECT T1.id
# FROM tv_channel AS T1
# JOIN country AS T2 ON T1.country_id = T2.id
# WHERE T2.num_tv_channels > 2;
# ```
#
# This query works as follows:
#
# - It selects the id column from the tv_channel table (aliased as T1).
# - It joins the tv_channel table with the country table (aliased as T2) on the country_id column.
# - It filters the results to include only the rows where the num_tv_channels column in the country table is greater than 2.
#
# However, the above query will return the id of the tv channels, but it will not return the country name. If you want to include the country name in the output, you can modify the query as follows:
#
# ```sql
# SELECT T1.id, T2.country_name
# FROM tv_channel AS T1
# JOIN country AS T2 ON T1.country_id = T2.id
# WHERE T2.num_tv_channels > 2
# SQL CORRETA: SELECT id FROM tv_channel GROUP BY country HAVING count(*)  >  2
#   -> FALHA (Erro de execução SQL: no such table: country)
#
# --- AVALIANDO ITEM 643/1034 | BANCO DE DADOS: tvshow ---
# PERGUNTA: What are the ids of all tv channels that have more than 2 TV channels?
# SQL GERADA: SELECT id
# FROM tv_channel
# WHERE id IN (
#   SELECT channel_id
#   FROM tv_channel
#   GROUP BY channel_id
#   HAVING COUNT(*) > 2
# )
# SQL CORRETA: SELECT id FROM tv_channel GROUP BY country HAVING count(*)  >  2
#   -> FALHA (Erro de execução SQL: no such column: channel_id)
#
# --- AVALIANDO ITEM 644/1034 | BANCO DE DADOS: tvshow ---
# PERGUNTA: find the id of tv channels that do not play any cartoon directed by Ben Jones.
# SQL GERADA: SELECT T1.id
# FROM tv_channel AS T1
# LEFT JOIN movie AS T2 ON T1.id = T2.channel_id
# LEFT JOIN cartoon AS T3 ON T2.id = T3.movie_id
# WHERE T3.director = 'Ben Jones' AND T3.id IS NULL
# SQL CORRETA: SELECT id FROM TV_Channel EXCEPT SELECT channel FROM cartoon WHERE directed_by  =  'Ben Jones'
#   -> FALHA (Erro de execução SQL: no such table: movie)
#
# --- AVALIANDO ITEM 645/1034 | BANCO DE DADOS: tvshow ---
# PERGUNTA: What are the ids of the TV channels that do not have any cartoons directed by Ben Jones?
# SQL GERADA: SELECT T1.id
# FROM tv_channel AS T1
# LEFT JOIN cartoon AS T2 ON T1.id = T2.tv_channel_id
# LEFT JOIN director AS T3 ON T2.director_id = T3.id
# WHERE T3.name = 'Ben Jones' AND T2.title IS NULL
# SQL CORRETA: SELECT id FROM TV_Channel EXCEPT SELECT channel FROM cartoon WHERE directed_by  =  'Ben Jones'
#   -> FALHA (Erro de execução SQL: no such table: director)
#
# --- AVALIANDO ITEM 646/1034 | BANCO DE DADOS: tvshow ---
# PERGUNTA: find the package option of the tv channel that do not have any cartoon directed by Ben Jones.
# SQL GERADA: To translate the given natural language question into a SQL query, we need to break down the question and identify the relevant tables, columns, joins, and aggregations.
#
# Question: Find the package option of the TV channel that do not have any cartoon directed by Ben Jones.
#
# Table: culture_company (contains information about TV channels)
# Table: book_club (contains information about books and their publishers)
# Table: movie (contains information about movies, including directors and budgets)
#
# Columns:
# - culture_company: company_name
# - book_club: book_club_id, publisher
# - movie: title, YEAR, director, budget_million
#
# Join: culture_company and book_club on book_club_id
# Join: movie on movie_id (assuming movie_id is the foreign key in book_club)
#
# To find the package option of the TV channel that do not have any cartoon directed by Ben Jones, we need to exclude the cartoons directed by Ben Jones from the TV channels. We can achieve this by using a NOT EXISTS clause in the SQL query.
#
# Here's the SQL query:
#
# ```sql
# SELECT T1.package_option
# FROM culture_company AS T1
# WHERE NOT EXISTS (
#   SELECT 1
#   FROM book_club AS T2
#   JOIN movie AS T3
# SQL CORRETA: SELECT package_option FROM TV_Channel WHERE id NOT IN (SELECT channel FROM cartoon WHERE directed_by  =  'Ben Jones')
#   -> FALHA (Erro de execução SQL: near "To": syntax error)
#
# --- AVALIANDO ITEM 647/1034 | BANCO DE DADOS: tvshow ---
# PERGUNTA: What are the package options of all tv channels that are not playing any cartoons directed by Ben Jones?
# SQL GERADA: SELECT tv_channels.package_option
# FROM tv_channels
# JOIN tv_schedule ON tv_channels.channel_name = tv_schedule.tv_channel_id
# WHERE tv_schedule.title NOT IN (
#   SELECT title
#   FROM cartoons
#   WHERE director = 'Ben Jones'
# )
# SQL CORRETA: SELECT package_option FROM TV_Channel WHERE id NOT IN (SELECT channel FROM cartoon WHERE directed_by  =  'Ben Jones')
#   -> FALHA (Erro de execução SQL: no such table: tv_channels)
#
# --- AVALIANDO ITEM 648/1034 | BANCO DE DADOS: poker_player ---
# PERGUNTA: How many poker players are there?
# SQL GERADA: SELECT COUNT(*)
# FROM player
# WHERE game = 'poker'
# SQL CORRETA: SELECT count(*) FROM poker_player
#   -> FALHA (Erro de execução SQL: no such table: player)
#
# --- AVALIANDO ITEM 649/1034 | BANCO DE DADOS: poker_player ---
# PERGUNTA: Count the number of poker players.
# SQL GERADA: SELECT COUNT(DISTINCT T1.name)
# FROM player AS T1
# JOIN game AS T2 ON T1.id = T2.player_id
# JOIN poker_hand AS T3 ON T2.id = T3.game_id
# WHERE T3.poker_hand = 'poker'
# SQL CORRETA: SELECT count(*) FROM poker_player
#   -> FALHA (Erro de execução SQL: no such table: player)
#
# --- AVALIANDO ITEM 650/1034 | BANCO DE DADOS: poker_player ---
# PERGUNTA: List the earnings of poker players in descending order.
# SQL GERADA: SELECT player_name, earnings
# FROM poker_player
# ORDER BY earnings DESC
# SQL CORRETA: SELECT Earnings FROM poker_player ORDER BY Earnings DESC
#   -> FALHA (Erro de execução SQL: no such column: player_name)
#
# --- AVALIANDO ITEM 651/1034 | BANCO DE DADOS: poker_player ---
# PERGUNTA: What are the earnings of poker players, ordered descending by value?
# SQL GERADA: SELECT game.earnings
# FROM game
# JOIN player ON game.player_id = player.player_id
# ORDER BY earnings DESC
# SQL CORRETA: SELECT Earnings FROM poker_player ORDER BY Earnings DESC
#   -> FALHA (Erro de execução SQL: no such table: game)
#
# --- AVALIANDO ITEM 652/1034 | BANCO DE DADOS: poker_player ---
# PERGUNTA: List the final tables made and the best finishes of poker players.
# SQL GERADA: SELECT
#     T1.title,
#     T1.YEAR,
#     T1.director,
#     T2.final_table,
#     T2.best_finish
# FROM
#     movie AS T1
# LEFT JOIN
#     poker_player AS T2 ON T1.title = T2.title
# WHERE
#     T2.best_finish = (SELECT MAX(best_finish) FROM poker_player)
# SQL CORRETA: SELECT Final_Table_Made ,  Best_Finish FROM poker_player
#   -> FALHA (Erro de execução SQL: no such table: movie)
#
# --- AVALIANDO ITEM 653/1034 | BANCO DE DADOS: poker_player ---
# PERGUNTA: What are the final tables made and best finishes for all poker players?
# SQL GERADA: SELECT
#     p.player_name,
#     t.tournament_name,
#     tr.finish,
#     tr.table_number
# FROM
#     poker_players p
# JOIN
#     poker_tournaments t ON p.tournament_id = t.tournament_id
# JOIN
#     tournament_results tr ON p.player_id = tr.player_id
# WHERE
#     tr.finish = 'best' AND tr.table_number = 'final'
# SQL CORRETA: SELECT Final_Table_Made ,  Best_Finish FROM poker_player
#   -> FALHA (Erro de execução SQL: no such table: poker_players)
#
# --- AVALIANDO ITEM 654/1034 | BANCO DE DADOS: poker_player ---
# PERGUNTA: What is the average earnings of poker players?
# SQL GERADA: SELECT AVG(earnings) AS average_earnings
# FROM player
# JOIN game ON player.player_id = game.player_id
# JOIN earnings ON player.player_id = earnings.player_id
# SQL CORRETA: SELECT avg(Earnings) FROM poker_player
#   -> FALHA (Erro de execução SQL: no such table: player)
#
# --- AVALIANDO ITEM 655/1034 | BANCO DE DADOS: poker_player ---
# PERGUNTA: Return the average earnings across all poker players.
# SQL GERADA: SELECT avg(earnings)
# FROM poker_player
# JOIN earnings ON poker_player.id = earnings.player_id
# SQL CORRETA: SELECT avg(Earnings) FROM poker_player
#   -> FALHA (Erro de execução SQL: no such table: earnings)
#
# --- AVALIANDO ITEM 656/1034 | BANCO DE DADOS: poker_player ---
# PERGUNTA: What is the money rank of the poker player with the highest earnings?
# SQL GERADA: SELECT
#     player.name AS 'Player Name',
#     tournament.tournament_name AS 'Tournament Name',
#     tournament.tournament_date AS 'Tournament Date',
#     tournament.tournament_earnings AS 'Earnings',
#     DENSE_RANK() OVER (ORDER BY tournament.tournament_earnings DESC) AS 'Money Rank'
# FROM
#     player
# JOIN
#     tournament ON player.player_id = tournament.player_id
# ORDER BY
#     tournament.tournament_earnings DESC
# SQL CORRETA: SELECT Money_Rank FROM poker_player ORDER BY Earnings DESC LIMIT 1
#   -> FALHA (Erro de execução SQL: no such table: player)
#
# --- AVALIANDO ITEM 657/1034 | BANCO DE DADOS: poker_player ---
# PERGUNTA: Return the money rank of the player with the greatest earnings.
# SQL GERADA: SELECT money_rank
# FROM player
# ORDER BY earnings DESC
# LIMIT 1
# SQL CORRETA: SELECT Money_Rank FROM poker_player ORDER BY Earnings DESC LIMIT 1
#   -> FALHA (Erro de execução SQL: no such table: player)
#
# --- AVALIANDO ITEM 658/1034 | BANCO DE DADOS: poker_player ---
# PERGUNTA: What is the maximum number of final tables made among poker players with earnings less than 200000?
# SQL GERADA: SELECT MAX(final_tables.table_id)
# FROM poker_players AS T1
# JOIN final_tables AS T2 ON T1.player_id = T2.player_id
# WHERE T1.earnings < 200000
# SQL CORRETA: SELECT max(Final_Table_Made) FROM poker_player WHERE Earnings  <  200000
#   -> FALHA (Erro de execução SQL: no such table: poker_players)
#
# --- AVALIANDO ITEM 659/1034 | BANCO DE DADOS: poker_player ---
# PERGUNTA: Return the maximum final tables made across all poker players who have earnings below 200000.
# SQL GERADA: SELECT MAX(t.table_size) AS max_final_tables
# FROM poker_players p
# JOIN poker_games g ON p.player_id = g.player_id
# JOIN poker_tables t ON g.game_id = t.game_id
# WHERE p.earnings < 200000
# SQL CORRETA: SELECT max(Final_Table_Made) FROM poker_player WHERE Earnings  <  200000
#   -> FALHA (Erro de execução SQL: no such table: poker_players)
#
# --- AVALIANDO ITEM 660/1034 | BANCO DE DADOS: poker_player ---
# PERGUNTA: What are the names of poker players?
# SQL GERADA: SELECT name FROM player WHERE game = 'poker'
# SQL CORRETA: SELECT T1.Name FROM people AS T1 JOIN poker_player AS T2 ON T1.People_ID  =  T2.People_ID
#   -> FALHA (Erro de execução SQL: no such table: player)
#
# --- AVALIANDO ITEM 661/1034 | BANCO DE DADOS: poker_player ---
# PERGUNTA: Return the names of all the poker players.
# SQL GERADA: SELECT player_name
# FROM poker_player
# SQL CORRETA: SELECT T1.Name FROM people AS T1 JOIN poker_player AS T2 ON T1.People_ID  =  T2.People_ID
#   -> FALHA (Erro de execução SQL: no such column: player_name)
#
# --- AVALIANDO ITEM 662/1034 | BANCO DE DADOS: poker_player ---
# PERGUNTA: What are the names of poker players whose earnings is higher than 300000?
# SQL GERADA: To translate the given natural language question into a SQL query, we can follow these steps:
#
# Question: What are the names of poker players whose earnings is higher than 300000?
#
# Table: poker_players
# Columns: name, earnings
#
# SQL Query:
# SELECT name FROM poker_players WHERE earnings > 300000
# SQL CORRETA: SELECT T1.Name FROM people AS T1 JOIN poker_player AS T2 ON T1.People_ID  =  T2.People_ID WHERE T2.Earnings  >  300000
#   -> FALHA (Erro de execução SQL: near "To": syntax error)
#
# --- AVALIANDO ITEM 663/1034 | BANCO DE DADOS: poker_player ---
# PERGUNTA: Give the names of poker players who have earnings above 300000.
# SQL GERADA: SELECT name
# FROM poker_players
# WHERE earnings > 300000
# SQL CORRETA: SELECT T1.Name FROM people AS T1 JOIN poker_player AS T2 ON T1.People_ID  =  T2.People_ID WHERE T2.Earnings  >  300000
#   -> FALHA (Erro de execução SQL: no such table: poker_players)
#
# --- AVALIANDO ITEM 664/1034 | BANCO DE DADOS: poker_player ---
# PERGUNTA: List the names of poker players ordered by the final tables made in ascending order.
# SQL GERADA: SELECT player_name
# FROM poker_player
# ORDER BY final_table ASC
# SQL CORRETA: SELECT T1.Name FROM people AS T1 JOIN poker_player AS T2 ON T1.People_ID  =  T2.People_ID ORDER BY T2.Final_Table_Made
#   -> FALHA (Erro de execução SQL: no such column: player_name)
#
# --- AVALIANDO ITEM 665/1034 | BANCO DE DADOS: poker_player ---
# PERGUNTA: What are the names of poker players, ordered ascending by the number of final tables they have made?
# SQL GERADA: SELECT name
# FROM player
# ORDER BY final_tables ASC
# SQL CORRETA: SELECT T1.Name FROM people AS T1 JOIN poker_player AS T2 ON T1.People_ID  =  T2.People_ID ORDER BY T2.Final_Table_Made
#   -> FALHA (Erro de execução SQL: no such table: player)
#
# --- AVALIANDO ITEM 666/1034 | BANCO DE DADOS: poker_player ---
# PERGUNTA: What is the birth date of the poker player with the lowest earnings?
# SQL GERADA: SELECT player.birth_date
# FROM player
# JOIN tournament ON player.player_id = tournament.player_id
# WHERE tournament.earnings = (SELECT MIN(earnings) FROM tournament)
# SQL CORRETA: SELECT T1.Birth_Date FROM people AS T1 JOIN poker_player AS T2 ON T1.People_ID  =  T2.People_ID ORDER BY T2.Earnings ASC LIMIT 1
#   -> FALHA (Erro de execução SQL: no such table: player)
#
# --- AVALIANDO ITEM 667/1034 | BANCO DE DADOS: poker_player ---
# PERGUNTA: Return the birth date of the poker player with the lowest earnings.
# SQL GERADA: SELECT birth_date FROM poker_player ORDER BY earnings ASC LIMIT 1
# SQL CORRETA: SELECT T1.Birth_Date FROM people AS T1 JOIN poker_player AS T2 ON T1.People_ID  =  T2.People_ID ORDER BY T2.Earnings ASC LIMIT 1
#   -> FALHA (Erro de execução SQL: no such column: birth_date)
#
# --- AVALIANDO ITEM 668/1034 | BANCO DE DADOS: poker_player ---
# PERGUNTA: What is the money rank of the tallest poker player?
# SQL GERADA: SELECT poker_game.rank
# FROM player
# JOIN poker_game ON player.player_id = poker_game.player_id
# WHERE player.height = (SELECT MAX(height) FROM player)
# ORDER BY poker_game.rank DESC
# LIMIT 1
# SQL CORRETA: SELECT T2.Money_Rank FROM people AS T1 JOIN poker_player AS T2 ON T1.People_ID  =  T2.People_ID ORDER BY T1.Height DESC LIMIT 1
#   -> FALHA (Erro de execução SQL: no such table: player)
#
# --- AVALIANDO ITEM 669/1034 | BANCO DE DADOS: poker_player ---
# PERGUNTA: Return the money rank of the poker player with the greatest height.
# SQL GERADA: SELECT money_rank
# FROM (
#   SELECT money_rank, MAX(height) AS max_height
#   FROM players
#   GROUP BY money_rank
# ) AS subquery
# WHERE max_height = (SELECT MAX(height) FROM players);
# ```
#
# However, this query might not be the most efficient way to solve the problem, as it involves subqueries and grouping.
#
# A more efficient way to solve the problem would be to use a single query with a window function, like this:
#
# ```sql
# SELECT money_rank,
#        ROW_NUMBER() OVER (ORDER BY height DESC) AS rank
# FROM (
#   SELECT money_rank, height
#   FROM players
# ) AS subquery
# WHERE rank = 1
# SQL CORRETA: SELECT T2.Money_Rank FROM people AS T1 JOIN poker_player AS T2 ON T1.People_ID  =  T2.People_ID ORDER BY T1.Height DESC LIMIT 1
#   -> FALHA (Erro de execução SQL: no such table: players)
#
# --- AVALIANDO ITEM 670/1034 | BANCO DE DADOS: poker_player ---
# PERGUNTA: What is the average earnings of poker players with height higher than 200?
# SQL GERADA: SELECT AVG(earnings) AS average_earnings
# FROM poker_game
# WHERE player IN (
#   SELECT id
#   FROM player
#   WHERE height > 200
# )
# SQL CORRETA: SELECT avg(T2.Earnings) FROM people AS T1 JOIN poker_player AS T2 ON T1.People_ID  =  T2.People_ID WHERE T1.Height  >  200
#   -> FALHA (Erro de execução SQL: no such table: poker_game)
#
# --- AVALIANDO ITEM 671/1034 | BANCO DE DADOS: poker_player ---
# PERGUNTA: Give average earnings of poker players who are taller than 200.
# SQL GERADA: SELECT AVG(earnings) AS average_earnings
# FROM poker_game
# WHERE player_height > 200
# SQL CORRETA: SELECT avg(T2.Earnings) FROM people AS T1 JOIN poker_player AS T2 ON T1.People_ID  =  T2.People_ID WHERE T1.Height  >  200
#   -> FALHA (Erro de execução SQL: no such table: poker_game)
#
# --- AVALIANDO ITEM 672/1034 | BANCO DE DADOS: poker_player ---
# PERGUNTA: What are the names of poker players in descending order of earnings?
# SQL GERADA: SELECT player_name
# FROM poker_player
# JOIN poker_earnings ON poker_player.player_id = poker_earnings.player_id
# ORDER BY earnings DESC
# SQL CORRETA: SELECT T1.Name FROM people AS T1 JOIN poker_player AS T2 ON T1.People_ID  =  T2.People_ID ORDER BY T2.Earnings DESC
#   -> FALHA (Erro de execução SQL: no such table: poker_earnings)
#
# --- AVALIANDO ITEM 673/1034 | BANCO DE DADOS: poker_player ---
# PERGUNTA: Return the names of poker players sorted by their earnings descending.
# SQL GERADA: SELECT player_name FROM poker_player ORDER BY earnings DESC
# SQL CORRETA: SELECT T1.Name FROM people AS T1 JOIN poker_player AS T2 ON T1.People_ID  =  T2.People_ID ORDER BY T2.Earnings DESC
#   -> FALHA (Erro de execução SQL: no such column: player_name)
#
# --- AVALIANDO ITEM 674/1034 | BANCO DE DADOS: poker_player ---
# PERGUNTA: What are different nationalities of people and the corresponding number of people from each nation?
# SQL GERADA: SELECT nationality, COUNT(*) AS num_people
# FROM people
# GROUP BY nationality
# ORDER BY num_people DESC
# SQL CORRETA: SELECT Nationality ,  COUNT(*) FROM people GROUP BY Nationality
#   -> FALHA (Resultado diferente do esperado)
#
# --- AVALIANDO ITEM 675/1034 | BANCO DE DADOS: poker_player ---
# PERGUNTA: How many people are there of each nationality?
# SQL GERADA: SELECT nationality, count
# FROM people
# GROUP BY nationality
# ORDER BY count DESC
# SQL CORRETA: SELECT Nationality ,  COUNT(*) FROM people GROUP BY Nationality
#   -> FALHA (Erro de execução SQL: no such column: count)
#
# --- AVALIANDO ITEM 676/1034 | BANCO DE DADOS: poker_player ---
# PERGUNTA: What is the most common nationality of people?
# SQL GERADA: SELECT nationality, COUNT(*) as frequency
# FROM people
# JOIN nationality ON people.nationality_id = nationality.nationality_id
# GROUP BY nationality
# ORDER BY frequency DESC
# LIMIT 1
# SQL CORRETA: SELECT Nationality FROM people GROUP BY Nationality ORDER BY COUNT(*) DESC LIMIT 1
#   -> FALHA (Erro de execução SQL: no such table: nationality)
#
# --- AVALIANDO ITEM 677/1034 | BANCO DE DADOS: poker_player ---
# PERGUNTA: Give the nationality that is most common across all people.
# SQL GERADA: SELECT nationality
# FROM person
# GROUP BY nationality
# ORDER BY COUNT(*) DESC
# LIMIT 1
# SQL CORRETA: SELECT Nationality FROM people GROUP BY Nationality ORDER BY COUNT(*) DESC LIMIT 1
#   -> FALHA (Erro de execução SQL: no such table: person)
#
# --- AVALIANDO ITEM 678/1034 | BANCO DE DADOS: poker_player ---
# PERGUNTA: What are the nationalities that are shared by at least two people?
# SQL GERADA: SELECT nationality
# FROM person
# GROUP BY nationality
# HAVING COUNT(person_id) > 1
# SQL CORRETA: SELECT Nationality FROM people GROUP BY Nationality HAVING COUNT(*)  >=  2
#   -> FALHA (Erro de execução SQL: no such table: person)
#
# --- AVALIANDO ITEM 679/1034 | BANCO DE DADOS: poker_player ---
# PERGUNTA: Return the nationalities for which there are two or more people.
# SQL GERADA: SELECT nationality
# FROM person
# GROUP BY nationality
# HAVING COUNT(*) >= 2
# SQL CORRETA: SELECT Nationality FROM people GROUP BY Nationality HAVING COUNT(*)  >=  2
#   -> FALHA (Erro de execução SQL: no such table: person)
#
# --- AVALIANDO ITEM 680/1034 | BANCO DE DADOS: poker_player ---
# PERGUNTA: List the names and birth dates of people in ascending alphabetical order of name.
# SQL GERADA: SELECT first_name, last_name, birth_date
# FROM person
# ORDER BY first_name ASC, last_name ASC
# SQL CORRETA: SELECT Name ,  Birth_Date FROM people ORDER BY Name ASC
#   -> FALHA (Erro de execução SQL: no such table: person)
#
# --- AVALIANDO ITEM 681/1034 | BANCO DE DADOS: poker_player ---
# PERGUNTA: What are the names and birth dates of people, ordered by their names in alphabetical order?
# SQL GERADA: SELECT name, birth_date
# FROM person
# ORDER BY name ASC
# SQL CORRETA: SELECT Name ,  Birth_Date FROM people ORDER BY Name ASC
#   -> FALHA (Erro de execução SQL: no such table: person)
#
# --- AVALIANDO ITEM 682/1034 | BANCO DE DADOS: poker_player ---
# PERGUNTA: Show names of people whose nationality is not "Russia".
# SQL GERADA: SELECT name FROM person
# WHERE nationality!= 'Russia'
# SQL CORRETA: SELECT Name FROM people WHERE Nationality != "Russia"
#   -> FALHA (Erro de execução SQL: no such table: person)
#
# --- AVALIANDO ITEM 683/1034 | BANCO DE DADOS: poker_player ---
# PERGUNTA: What are the names of people who are not from Russia?
# SQL GERADA: SELECT T1.first_name, T1.last_name
# FROM person AS T1
# LEFT JOIN nationality AS T2 ON T1.nationality_id = T2.nationality_id
# WHERE T2.country!= 'Russia'
# SQL CORRETA: SELECT Name FROM people WHERE Nationality != "Russia"
#   -> FALHA (Erro de execução SQL: no such table: person)
#
# --- AVALIANDO ITEM 684/1034 | BANCO DE DADOS: poker_player ---
# PERGUNTA: List the names of people that are not poker players.
# SQL GERADA: To translate the given natural language question into a SQL query, we need to identify the relevant tables, columns, joins, and aggregations. Here's the SQL query for the given question:
#
# Question: List the names of people that are not poker players.
#
# SQL:
# SELECT T1.first_name, T1.last_name
# FROM person AS T1
# LEFT JOIN player AS T2 ON T1.person_id = T2.person_id
# WHERE T2.game = 'poker'
# AND T1.first_name IS NOT NULL
# AND T1.last_name IS NOT NULL
# SQL CORRETA: SELECT Name FROM people WHERE People_ID NOT IN (SELECT People_ID FROM poker_player)
#   -> FALHA (Erro de execução SQL: near "To": syntax error)
#
# --- AVALIANDO ITEM 685/1034 | BANCO DE DADOS: poker_player ---
# PERGUNTA: What are the names of people who do not play poker?
# SQL GERADA: SELECT name
# FROM people
# WHERE name NOT IN (SELECT player FROM poker)
# SQL CORRETA: SELECT Name FROM people WHERE People_ID NOT IN (SELECT People_ID FROM poker_player)
#   -> FALHA (Erro de execução SQL: no such table: poker)
#
# --- AVALIANDO ITEM 686/1034 | BANCO DE DADOS: poker_player ---
# PERGUNTA: How many distinct nationalities are there?
# SQL GERADA: SELECT COUNT(DISTINCT nationality)
# FROM person
# WHERE nationality IS NOT NULL;
# ```
#
# However, this query only considers the 'person' table. If we want to consider the'movie' table as well, we can use a LEFT JOIN to combine the two tables:
#
# ```sql
# SELECT COUNT(DISTINCT nationality)
# FROM person
# LEFT JOIN movie ON person.id = movie.director
# WHERE person.nationality IS NOT NULL;
# ```
#
# But this query will count each nationality multiple times if a person has directed multiple movies. To avoid this, we can use a GROUP BY clause to group the results by nationality:
#
# ```sql
# SELECT COUNT(DISTINCT nationality)
# FROM person
# LEFT JOIN movie ON person.id = movie.director
# WHERE person.nationality IS NOT NULL
# GROUP BY nationality
# SQL CORRETA: SELECT count(DISTINCT Nationality) FROM people
#   -> FALHA (Erro de execução SQL: no such table: person)
#
# --- AVALIANDO ITEM 687/1034 | BANCO DE DADOS: poker_player ---
# PERGUNTA: Count the number of different nationalities.
# SQL GERADA: SELECT COUNT(DISTINCT nationality) FROM person
# SQL CORRETA: SELECT count(DISTINCT Nationality) FROM people
#   -> FALHA (Erro de execução SQL: no such table: person)
#
# --- AVALIANDO ITEM 688/1034 | BANCO DE DADOS: voter_1 ---
# PERGUNTA: How many states are there?
# SQL GERADA: SELECT COUNT(*)
# FROM state
# SQL CORRETA: SELECT count(*) FROM area_code_state
#   -> FALHA (Erro de execução SQL: no such table: state)
#
# --- AVALIANDO ITEM 689/1034 | BANCO DE DADOS: voter_1 ---
# PERGUNTA: List the contestant numbers and names, ordered by contestant name descending.
# SQL GERADA: SELECT contestant_number, contestant_name FROM contestant ORDER BY contestant_name DESC
# SQL CORRETA: SELECT contestant_number ,  contestant_name FROM contestants ORDER BY contestant_name DESC
#   -> FALHA (Erro de execução SQL: no such table: contestant)
#
# --- AVALIANDO ITEM 690/1034 | BANCO DE DADOS: voter_1 ---
# PERGUNTA: List the vote ids, phone numbers and states of all votes.
# SQL GERADA: SELECT vote_id, phone_number, state FROM vote
# SQL CORRETA: SELECT vote_id ,  phone_number ,  state FROM votes
#   -> FALHA (Erro de execução SQL: no such table: vote)
#
# --- AVALIANDO ITEM 691/1034 | BANCO DE DADOS: voter_1 ---
# PERGUNTA: What are the maximum and minimum values of area codes?
# SQL GERADA: SELECT max(area_code), min(area_code) FROM location
# SQL CORRETA: SELECT max(area_code) ,  min(area_code) FROM area_code_state
#   -> FALHA (Erro de execução SQL: no such table: location)
#
# --- AVALIANDO ITEM 692/1034 | BANCO DE DADOS: voter_1 ---
# PERGUNTA: What is last date created of votes from the state 'CA'?
# SQL GERADA: SELECT MAX(created_at) AS last_date_created
# FROM votes
# WHERE state = 'CA'
# SQL CORRETA: SELECT max(created) FROM votes WHERE state  =  'CA'
#   -> FALHA (Erro de execução SQL: no such column: created_at)
#
# --- AVALIANDO ITEM 693/1034 | BANCO DE DADOS: voter_1 ---
# PERGUNTA: What are the names of the contestants whose names are not 'Jessie Alloway'
# SQL GERADA: SELECT T1.name
# FROM contestant AS T1
# WHERE T1.name!= 'Jessie Alloway'
# SQL CORRETA: SELECT contestant_name FROM contestants WHERE contestant_name != 'Jessie Alloway'
#   -> FALHA (Erro de execução SQL: no such table: contestant)
#
# --- AVALIANDO ITEM 694/1034 | BANCO DE DADOS: voter_1 ---
# PERGUNTA: What are the distinct states and create time of all votes?
# SQL GERADA: SELECT DISTINCT state, create_time
# FROM vote
# SQL CORRETA: SELECT DISTINCT state ,  created FROM votes
#   -> FALHA (Erro de execução SQL: no such table: vote)
#
# --- AVALIANDO ITEM 695/1034 | BANCO DE DADOS: voter_1 ---
# PERGUNTA: What are the contestant numbers and names of the contestants who had at least two votes?
# SQL GERADA: SELECT contestants.contestant_number, contestants.contestant_name
# FROM contestants
# JOIN votes ON contestants.contestant_number = votes.contestant_number
# GROUP BY contestants.contestant_number, contestants.contestant_name
# HAVING COUNT(votes.vote_count) >= 2
# SQL CORRETA: SELECT T1.contestant_number , T1.contestant_name FROM contestants AS T1 JOIN votes AS T2 ON T1.contestant_number  =  T2.contestant_number GROUP BY T1.contestant_number HAVING count(*)  >=  2
#   -> FALHA (Erro de execução SQL: no such column: votes.vote_count)
#
# --- AVALIANDO ITEM 696/1034 | BANCO DE DADOS: voter_1 ---
# PERGUNTA: Of all the contestants who got voted, what is the contestant number and name of the contestant who got least votes?
# SQL GERADA: SELECT contestant_number, contestant_name
# FROM contestant_votes
# WHERE votes = (SELECT MIN(votes) FROM contestant_votes);
# ```
#
# This query works as follows:
#
# - It selects the `contestant_number` and `contestant_name` from the `contestant_votes` table.
# - The subquery `(SELECT MIN(votes) FROM contestant_votes)` finds the minimum number of votes in the `contestant_votes` table.
# - The outer query selects the `contestant_number` and `contestant_name` from the `contestant_votes` table where the `votes` column is equal to the minimum number of votes found by the subquery.
#
# However, this query will return multiple rows if there are multiple contestants who got the least votes. If you want to return only one row, you can use the `LIMIT` clause:
#
# ```sql
# SELECT contestant_number, contestant_name
# FROM contestant_votes
# WHERE votes = (SELECT MIN(votes) FROM contestant_votes)
# LIMIT 1
# SQL CORRETA: SELECT T1.contestant_number , T1.contestant_name FROM contestants AS T1 JOIN votes AS T2 ON T1.contestant_number  =  T2.contestant_number GROUP BY T1.contestant_number ORDER BY count(*) ASC LIMIT 1
#   -> FALHA (Erro de execução SQL: no such table: contestant_votes)
#
# --- AVALIANDO ITEM 697/1034 | BANCO DE DADOS: voter_1 ---
# PERGUNTA: What are the number of votes from state 'NY' or 'CA'?
# SQL GERADA: SELECT COUNT(*)
# FROM vote
# WHERE state IN ('NY', 'CA')
# SQL CORRETA: SELECT count(*) FROM votes WHERE state  =  'NY' OR state  =  'CA'
#   -> FALHA (Erro de execução SQL: no such table: vote)
#
# --- AVALIANDO ITEM 698/1034 | BANCO DE DADOS: voter_1 ---
# PERGUNTA: How many contestants did not get voted?
# SQL GERADA: SELECT COUNT(*)
# FROM contestants
# WHERE contestant_id NOT IN (SELECT contestant_id FROM votes)
# SQL CORRETA: SELECT count(*) FROM contestants WHERE contestant_number NOT IN ( SELECT contestant_number FROM votes )
#   -> FALHA (Erro de execução SQL: no such column: contestant_id)
#
# --- AVALIANDO ITEM 699/1034 | BANCO DE DADOS: voter_1 ---
# PERGUNTA: What is the area code in which the most voters voted?
# SQL GERADA: SELECT T1.area_code, COUNT(T1.votes) AS max_votes
# FROM voter AS T1
# JOIN election AS T2 ON T1.area_code = T2.area_code
# GROUP BY T1.area_code
# ORDER BY max_votes DESC
# LIMIT 1
# SQL CORRETA: SELECT T1.area_code FROM area_code_state AS T1 JOIN votes AS T2 ON T1.state  =  T2.state GROUP BY T1.area_code ORDER BY count(*) DESC LIMIT 1
#   -> FALHA (Erro de execução SQL: no such table: voter)
#
# --- AVALIANDO ITEM 700/1034 | BANCO DE DADOS: voter_1 ---
# PERGUNTA: What are the create dates, states, and phone numbers of the votes that were for the contestant named 'Tabatha Gehling'?
# SQL GERADA: SELECT create_date, state, phone_number
# FROM vote
# WHERE contestant_name = 'Tabatha Gehling'
# SQL CORRETA: SELECT T2.created ,  T2.state ,  T2.phone_number FROM contestants AS T1 JOIN votes AS T2 ON T1.contestant_number  =  T2.contestant_number WHERE T1.contestant_name  =  'Tabatha Gehling'
#   -> FALHA (Erro de execução SQL: no such table: vote)
#
# --- AVALIANDO ITEM 701/1034 | BANCO DE DADOS: voter_1 ---
# PERGUNTA: List the area codes in which voters voted both for the contestant 'Tabatha Gehling' and the contestant 'Kelly Clauss'.
# SQL GERADA: SELECT T1.area_code
# FROM voter AS T1
# JOIN voter_contestant AS T2 ON T1.area_code = T2.voter_area_code
# JOIN contestant AS T3 ON T2.contestant_id = T3.id
# WHERE T3.name IN ('Tabatha Gehling', 'Kelly Clauss')
# GROUP BY T1.area_code
# HAVING COUNT(T2.voted_for) > 1
# SQL CORRETA: SELECT T3.area_code FROM contestants AS T1 JOIN votes AS T2 ON T1.contestant_number  =  T2.contestant_number JOIN area_code_state AS T3 ON T2.state  =  T3.state WHERE T1.contestant_name  =  'Tabatha Gehling' INTERSECT SELECT T3.area_code FROM contestants AS T1 JOIN votes AS T2 ON T1.contestant_number  =  T2.contestant_number JOIN area_code_state AS T3 ON T2.state  =  T3.state WHERE T1.contestant_name  =  'Kelly Clauss'
#   -> FALHA (Erro de execução SQL: no such table: voter)
#
# --- AVALIANDO ITEM 702/1034 | BANCO DE DADOS: voter_1 ---
# PERGUNTA: Return the names of the contestants whose names contain the substring 'Al' .
# SQL GERADA: SELECT T1.name FROM contestant AS T1 JOIN competition AS T2 ON T1.competition_id = T2.competition_id WHERE T1.name LIKE '%Al%'
# SQL CORRETA: select contestant_name from contestants where contestant_name like "%al%"
#   -> FALHA (Erro de execução SQL: no such table: contestant)
#
# --- AVALIANDO ITEM 703/1034 | BANCO DE DADOS: world_1 ---
# PERGUNTA: What are the names of all the countries that became independent after 1950?
# SQL GERADA: SELECT T1.country_name
# FROM country AS T1
# JOIN independence AS T2 ON T1.country_id = T2.country_id
# WHERE T2.independence_year > 1950
# SQL CORRETA: SELECT Name FROM country WHERE IndepYear  >  1950
#   -> FALHA (Erro de execução SQL: no such table: independence)
#
# ...
# SQL GERADA: SELECT singer_name
# FROM singer
# ORDER BY net_worth ASC
# SQL CORRETA: SELECT Name FROM singer ORDER BY Net_Worth_Millions ASC
#   -> FALHA (Erro de execução SQL: no such column: singer_name)
#
# --- AVALIANDO ITEM 1005/1034 | BANCO DE DADOS: singer ---
# PERGUNTA: What are the birth year and citizenship of singers?
# SQL GERADA: SELECT singer.birth_year, singer.citizenship
# FROM singer
# JOIN song ON singer.singer_id = song.singer_id;
# ```
#
# However, this query will return the birth year and citizenship of all singers, not just those who are singers (i.e., artists who have released songs). To get the desired result, we need to modify the query to only consider rows where the singer is also a singer (i.e., an artist who has released songs).
#
# A more accurate query would be:
#
# ```sql
# SELECT singer.birth_year, singer.citizenship
# FROM singer
# WHERE singer_id IN (SELECT singer_id FROM song)
# SQL CORRETA: SELECT Birth_Year ,  Citizenship FROM singer
#   -> FALHA (Erro de execução SQL: You can only execute one statement at a time.)
#
# --- AVALIANDO ITEM 1006/1034 | BANCO DE DADOS: singer ---
# PERGUNTA: What are the birth years and citizenships of the singers?
# SQL GERADA: SELECT birth_year, citizenship
# FROM singers;
# ```
#
# However, if there are any relationships between singers and other entities, we might need to join the singers table with another table. For example, if we have a nationality table that contains information about the nationality of each singer, we might use the following query:
#
# ```sql
# SELECT s.birth_year, n.citizenship
# FROM singers s
# JOIN nationality n ON s.nationality_id = n.id;
# ```
#
# Or, if we have a country_of_origin table that contains information about the country of origin of each singer, we might use the following query:
# SQL CORRETA: SELECT Birth_Year ,  Citizenship FROM singer
#   -> FALHA (Erro de execução SQL: no such table: singers)
#
# --- AVALIANDO ITEM 1007/1034 | BANCO DE DADOS: singer ---
# PERGUNTA: List the name of singers whose citizenship is not "France".
# SQL GERADA: SELECT singer_name
# FROM singer
# WHERE country!= 'France'
# SQL CORRETA: SELECT Name FROM singer WHERE Citizenship != "France"
#   -> FALHA (Erro de execução SQL: no such column: singer_name)
#
# --- AVALIANDO ITEM 1008/1034 | BANCO DE DADOS: singer ---
# PERGUNTA: What are the names of the singers who are not French citizens?
# SQL GERADA: SELECT singer_name
# FROM singer
# WHERE nationality!= 'French'
# SQL CORRETA: SELECT Name FROM singer WHERE Citizenship != "France"
#   -> FALHA (Erro de execução SQL: no such column: singer_name)
#
# --- AVALIANDO ITEM 1009/1034 | BANCO DE DADOS: singer ---
# PERGUNTA: Show the name of singers whose birth year is either 1948 or 1949?
# SQL GERADA: SELECT T1.name
# FROM singer AS T1
# WHERE T1.birth_year IN (1948, 1949)
# SQL CORRETA: SELECT Name FROM singer WHERE Birth_Year  =  1948 OR Birth_Year  =  1949
#   -> SUCESSO (Resultados idênticos)
#
# --- AVALIANDO ITEM 1010/1034 | BANCO DE DADOS: singer ---
# PERGUNTA: What are the names of the singers whose birth years are either 1948 or 1949?
# SQL GERADA: SELECT singer_name
# FROM singer
# WHERE birth_year = 1948 OR birth_year = 1949
# SQL CORRETA: SELECT Name FROM singer WHERE Birth_Year  =  1948 OR Birth_Year  =  1949
#   -> FALHA (Erro de execução SQL: no such column: singer_name)
#
# --- AVALIANDO ITEM 1011/1034 | BANCO DE DADOS: singer ---
# PERGUNTA: What is the name of the singer with the largest net worth?
# SQL GERADA: SELECT T1.singer_name, max(T2.net_worth)
# FROM singer AS T1
# JOIN net_worth AS T2 ON T1.singer_id = T2.singer_id
# GROUP BY T1.singer_name
# ORDER BY T2.net_worth DESC
# LIMIT 1
# SQL CORRETA: SELECT Name FROM singer ORDER BY Net_Worth_Millions DESC LIMIT 1
#   -> FALHA (Erro de execução SQL: no such table: net_worth)
#
# --- AVALIANDO ITEM 1012/1034 | BANCO DE DADOS: singer ---
# PERGUNTA: What is the name of the singer who is worth the most?
# SQL GERADA: SELECT T1.name
# FROM singer AS T1
# JOIN musician_singer AS T2 ON T1.id = T2.singer_id
# WHERE T2.net_worth = (SELECT MAX(net_worth) FROM singer)
# SQL CORRETA: SELECT Name FROM singer ORDER BY Net_Worth_Millions DESC LIMIT 1
#   -> FALHA (Erro de execução SQL: no such table: musician_singer)
#
# --- AVALIANDO ITEM 1013/1034 | BANCO DE DADOS: singer ---
# PERGUNTA: Show different citizenship of singers and the number of singers of each citizenship.
# SQL GERADA: SELECT citizenship, COUNT(*) AS num_singers
# FROM singer
# GROUP BY citizenship
# ORDER BY num_singers DESC
# SQL CORRETA: SELECT Citizenship ,  COUNT(*) FROM singer GROUP BY Citizenship
#   -> FALHA (Resultado diferente do esperado)
#
# --- AVALIANDO ITEM 1014/1034 | BANCO DE DADOS: singer ---
# PERGUNTA: For each citizenship, how many singers are from that country?
# SQL GERADA: To answer the final task, we need to translate the natural language question into a SQL query. Here's the solution:
#
# Question: For each citizenship, how many singers are from that country?
#
# SQL:
# SELECT citizenship, COUNT(*) AS num_singers
# FROM singer
# GROUP BY citizenship
# SQL CORRETA: SELECT Citizenship ,  COUNT(*) FROM singer GROUP BY Citizenship
#   -> FALHA (Erro de execução SQL: near "To": syntax error)
#
# --- AVALIANDO ITEM 1015/1034 | BANCO DE DADOS: singer ---
# PERGUNTA: Please show the most common citizenship of singers.
# SQL GERADA: SELECT T1.citizenship, COUNT(T1.citizenship) AS frequency
# FROM singer AS T1
# JOIN singer_citizenship AS T2 ON T1.singer_id = T2.singer_id
# GROUP BY T1.citizenship
# ORDER BY frequency DESC
# LIMIT 1
# SQL CORRETA: SELECT Citizenship FROM singer GROUP BY Citizenship ORDER BY COUNT(*) DESC LIMIT 1
#   -> FALHA (Erro de execução SQL: no such table: singer_citizenship)
#
# --- AVALIANDO ITEM 1016/1034 | BANCO DE DADOS: singer ---
# PERGUNTA: What is the most common singer citizenship ?
# SQL GERADA: SELECT T1.singer_citizenship, COUNT(*) AS frequency
# FROM singer AS T1
# JOIN movie AS T2 ON T1.singer_name = T2.director
# GROUP BY T1.singer_citizenship
# ORDER BY frequency DESC
# LIMIT 1
# SQL CORRETA: select citizenship from singer group by citizenship order by count(*) desc limit 1
#   -> FALHA (Erro de execução SQL: no such table: movie)
#
# --- AVALIANDO ITEM 1017/1034 | BANCO DE DADOS: singer ---
# PERGUNTA: Show different citizenships and the maximum net worth of singers of each citizenship.
# SQL GERADA: SELECT T1.citizenship, MAX(T2.net_worth) AS max_net_worth
# FROM singer AS T1
# JOIN net_worth AS T2 ON T1.singer_id = T2.singer_id
# GROUP BY T1.citizenship
# SQL CORRETA: SELECT Citizenship ,  max(Net_Worth_Millions) FROM singer GROUP BY Citizenship
#   -> FALHA (Erro de execução SQL: no such table: net_worth)
#
# --- AVALIANDO ITEM 1018/1034 | BANCO DE DADOS: singer ---
# PERGUNTA: For each citizenship, what is the maximum net worth?
# SQL GERADA: SELECT T1.citizenship, MAX(T2.net_worth) AS max_net_worth
# FROM person AS T1
# LEFT JOIN asset AS T2 ON T1.id = T2.person_id
# GROUP BY T1.citizenship
# SQL CORRETA: SELECT Citizenship ,  max(Net_Worth_Millions) FROM singer GROUP BY Citizenship
#   -> FALHA (Erro de execução SQL: no such table: person)
#
# --- AVALIANDO ITEM 1019/1034 | BANCO DE DADOS: singer ---
# PERGUNTA: Show titles of songs and names of singers.
# SQL GERADA: SELECT song_title, singer_name
# FROM song
# SQL CORRETA: SELECT T2.Title ,  T1.Name FROM singer AS T1 JOIN song AS T2 ON T1.Singer_ID  =  T2.Singer_ID
#   -> FALHA (Erro de execução SQL: no such column: song_title)
#
# --- AVALIANDO ITEM 1020/1034 | BANCO DE DADOS: singer ---
# PERGUNTA: What are the song titles and singer names?
# SQL GERADA: SELECT song_title, singer_name
# FROM song
# SQL CORRETA: SELECT T2.Title ,  T1.Name FROM singer AS T1 JOIN song AS T2 ON T1.Singer_ID  =  T2.Singer_ID
#   -> FALHA (Erro de execução SQL: no such column: song_title)
#
# --- AVALIANDO ITEM 1021/1034 | BANCO DE DADOS: singer ---
# PERGUNTA: Show distinct names of singers that have songs with sales more than 300000.
# SQL GERADA: SELECT DISTINCT T1.artist_name
# FROM singer AS T1
# JOIN song AS T2 ON T1.artist_id = T2.artist_id
# JOIN sales AS T3 ON T2.song_id = T3.song_id
# WHERE T3.sales > 300000
# SQL CORRETA: SELECT DISTINCT T1.Name FROM singer AS T1 JOIN song AS T2 ON T1.Singer_ID  =  T2.Singer_ID WHERE T2.Sales  >  300000
#   -> FALHA (Erro de execução SQL: no such table: sales)
#
# --- AVALIANDO ITEM 1022/1034 | BANCO DE DADOS: singer ---
# PERGUNTA: what are the different names of the singers that have sales more than 300000?
# SQL GERADA: To translate the natural language question into a SQL query, we need to identify the relevant tables, columns, and conditions. Here's the SQL query for the given question:
#
# Question: what are the different names of the singers that have sales more than 300000?
#
# SQL:
# SELECT DISTINCT T1.singer_name
# FROM sales AS T1
# JOIN artist AS T2 ON T1.artist_id = T2.artist_id
# WHERE T1.sales_amount > 300000
# SQL CORRETA: SELECT DISTINCT T1.Name FROM singer AS T1 JOIN song AS T2 ON T1.Singer_ID  =  T2.Singer_ID WHERE T2.Sales  >  300000
#   -> FALHA (Erro de execução SQL: near "To": syntax error)
#
# --- AVALIANDO ITEM 1023/1034 | BANCO DE DADOS: singer ---
# PERGUNTA: Show the names of singers that have more than one song.
# SQL GERADA: SELECT singer_name
# FROM singer
# GROUP BY singer_name
# HAVING COUNT(song_id) > 1
# SQL CORRETA: SELECT T1.Name FROM singer AS T1 JOIN song AS T2 ON T1.Singer_ID  =  T2.Singer_ID GROUP BY T1.Name HAVING COUNT(*)  >  1
#   -> FALHA (Erro de execução SQL: no such column: singer_name)
#
# --- AVALIANDO ITEM 1024/1034 | BANCO DE DADOS: singer ---
# PERGUNTA: What are the names of the singers that have more than one songs?
# SQL GERADA: SELECT T1.singer_name
# FROM singer AS T1
# JOIN song AS T2 ON T1.singer_id = T2.singer_id
# GROUP BY T1.singer_name
# HAVING COUNT(T2.song_id) > 1
# SQL CORRETA: SELECT T1.Name FROM singer AS T1 JOIN song AS T2 ON T1.Singer_ID  =  T2.Singer_ID GROUP BY T1.Name HAVING COUNT(*)  >  1
#   -> FALHA (Erro de execução SQL: no such column: T1.singer_name)
#
# --- AVALIANDO ITEM 1025/1034 | BANCO DE DADOS: singer ---
# PERGUNTA: Show the names of singers and the total sales of their songs.
# SQL GERADA: SELECT singer.name, SUM(song.sales) AS total_sales
# FROM singer
# JOIN song ON singer.singer_id = song.singer_id
# GROUP BY singer.name
# ORDER BY total_sales DESC
# SQL CORRETA: SELECT T1.Name ,  sum(T2.Sales) FROM singer AS T1 JOIN song AS T2 ON T1.Singer_ID  =  T2.Singer_ID GROUP BY T1.Name
#   -> FALHA (Resultado diferente do esperado)
#
# --- AVALIANDO ITEM 1026/1034 | BANCO DE DADOS: singer ---
# PERGUNTA: For each singer name, what is the total sales for their songs?
# SQL GERADA: SELECT
#     s.singer_name,
#     SUM(ss.total_sales) AS total_sales
# FROM
#     singer s
# JOIN
#     singer_song ss ON s.singer_id = ss.singer_id
# GROUP BY
#     s.singer_name
# SQL CORRETA: SELECT T1.Name ,  sum(T2.Sales) FROM singer AS T1 JOIN song AS T2 ON T1.Singer_ID  =  T2.Singer_ID GROUP BY T1.Name
#   -> FALHA (Erro de execução SQL: no such table: singer_song)
#
# --- AVALIANDO ITEM 1027/1034 | BANCO DE DADOS: singer ---
# PERGUNTA: List the name of singers that do not have any song.
# SQL GERADA: To translate the given natural language question into a SQL query, we need to identify the relevant tables, columns, joins, and aggregations.
#
# The question is: "List the name of singers that do not have any song."
#
# Based on the provided examples, we can assume that there are two tables involved:'singer' and'song'. The'singer' table likely contains information about the singers, including their names. The'song' table contains information about the songs, including the singer's name.
#
# However, the provided examples do not explicitly mention a'song' table. We can assume that the'song' table is related to the'singer' table through a many-to-many relationship, and that the'song' table contains information about the songs, including the singer's name.
#
# To answer the question, we need to find the singers who do not have any songs in the'song' table. We can do this by using a LEFT JOIN to combine the'singer' and'song' tables, and then using a WHERE clause to filter out the singers who have songs.
#
# Here is the SQL query:
#
# ```sql
# SELECT T1.singer_name
# FROM singer AS T1
# LEFT JOIN song AS T2 ON T1.singer
# SQL CORRETA: SELECT Name FROM singer WHERE Singer_ID NOT IN (SELECT Singer_ID FROM song)
#   -> FALHA (Erro de execução SQL: near "To": syntax error)
#
# --- AVALIANDO ITEM 1028/1034 | BANCO DE DADOS: singer ---
# PERGUNTA: What is the sname of every sing that does not have any song?
# SQL GERADA: SELECT s.sname
# FROM sing s
# LEFT JOIN song song ON s.id = song.sing_id
# WHERE song.song_name IS NULL
# SQL CORRETA: SELECT Name FROM singer WHERE Singer_ID NOT IN (SELECT Singer_ID FROM song)
#   -> FALHA (Erro de execução SQL: no such table: sing)
#
# --- AVALIANDO ITEM 1029/1034 | BANCO DE DADOS: singer ---
# PERGUNTA: Show the citizenship shared by singers with birth year before 1945 and after 1955.
# SQL GERADA: SELECT T1.citizenship
# FROM singer AS T1
# JOIN movie AS T2 ON T1.id = T2.director_id
# WHERE T1.birth_year BETWEEN 1945 AND 1955
# GROUP BY T1.citizenship
# HAVING COUNT(T1.id) > 1
# SQL CORRETA: SELECT Citizenship FROM singer WHERE Birth_Year  <  1945 INTERSECT SELECT Citizenship FROM singer WHERE Birth_Year  >  1955
#   -> FALHA (Erro de execução SQL: no such table: movie)
#
# --- AVALIANDO ITEM 1030/1034 | BANCO DE DADOS: singer ---
# PERGUNTA: What are the citizenships that are shared by singers with a birth year before 1945 and after 1955?
# SQL GERADA: To answer the final task, we need to translate the natural language question into a SQL query. Here's the solution:
#
# Question: What are the citizenships that are shared by singers with a birth year before 1945 and after 1955?
#
# SQL:
# SELECT T1.citizenship
# FROM singer AS T1
# JOIN birth_year AS T2 ON T1.birth_year_id = T2.birth_year_id
# WHERE T2.birth_year BETWEEN 1945 AND 1955
# GROUP BY T1.citizenship
# HAVING COUNT(T1.singer_id) > 1
# SQL CORRETA: SELECT Citizenship FROM singer WHERE Birth_Year  <  1945 INTERSECT SELECT Citizenship FROM singer WHERE Birth_Year  >  1955
#   -> FALHA (Erro de execução SQL: near "To": syntax error)
#
# --- AVALIANDO ITEM 1031/1034 | BANCO DE DADOS: real_estate_properties ---
# PERGUNTA: How many available features are there in total?
# SQL GERADA: SELECT COUNT(*)
# FROM feature
# WHERE available = 'true'
# SQL CORRETA: SELECT count(*) FROM Other_Available_Features
#   -> FALHA (Erro de execução SQL: no such table: feature)
#
# --- AVALIANDO ITEM 1032/1034 | BANCO DE DADOS: real_estate_properties ---
# PERGUNTA: What is the feature type name of feature AirCon?
# SQL GERADA: SELECT feature_type_name
# FROM feature
# WHERE feature_name = 'AirCon'
# SQL CORRETA: SELECT T2.feature_type_name FROM Other_Available_Features AS T1 JOIN Ref_Feature_Types AS T2 ON T1.feature_type_code  =  T2.feature_type_code WHERE T1.feature_name  =  "AirCon"
#   -> FALHA (Erro de execução SQL: no such table: feature)
#
# --- AVALIANDO ITEM 1033/1034 | BANCO DE DADOS: real_estate_properties ---
# PERGUNTA: Show the property type descriptions of properties belonging to that code.
# SQL GERADA: SELECT PT.description
# FROM property AS P
# JOIN property_type AS PT ON P.property_type_id = PT.id
# WHERE P.code = 'that code'
# SQL CORRETA: SELECT T2.property_type_description FROM Properties AS T1 JOIN Ref_Property_Types AS T2 ON T1.property_type_code  =  T2.property_type_code GROUP BY T1.property_type_code
#   -> FALHA (Erro de execução SQL: no such table: property)
#
# --- AVALIANDO ITEM 1034/1034 | BANCO DE DADOS: real_estate_properties ---
# PERGUNTA: What are the names of properties that are either houses or apartments with more than 1 room?
# SQL GERADA: SELECT P.property_name
# FROM properties P
# WHERE P.property_type IN ('house', 'apartment')
# AND P.id IN (
#   SELECT R.property_id
#   FROM rooms R
#   WHERE R.room_count > 1
# )
# SQL CORRETA: SELECT property_name FROM Properties WHERE property_type_code  =  "House" UNION SELECT property_name FROM Properties WHERE property_type_code  =  "Apartment" AND room_count  >  1
#   -> FALHA (Erro de execução SQL: no such table: rooms)
#
#
# --- AVALIAÇÃO DO BASELINE CONCLUÍDA ---
# Total de Perguntas Avaliadas: 1034
# Sucessos: 36
# Falhas: 998
# Taxa de Sucesso (Execution Accuracy): 3.48%
